# %%
import pandas as pd

# %%
# df1 = pd.read_json('/home/xubeiyu/projects/Schemalinking/Data/MMQA/Synthesized_two_table_with_spider_db_id.json')
df2 = pd.read_json('/home/xubeiyu/projects/Schemalinking/Data/MMQA/Synthesized_three_table_with_spider_db_id.json')

# %%
schema_path = 'Data/spider/database/department_store/schema description.csv'
total_schema_df = pd.read_csv(schema_path)

# %%
idx = 430
# print(df.iloc[0].to_markdown())

# print(df2.iloc[idx].to_markdown())
required = ['Addresses','Customers']
print(total_schema_df)
required_df = total_schema_df[total_schema_df['table_name'].isin(required)]
print(required_df)
# Out:
#                       table_name             column_name      data_type  \
# 0                      Addresses              address_id        INTEGER
# 1                      Addresses         address_details   VARCHAR(255)
# 2             Customer_Addresses             customer_id        INTEGER
# 3             Customer_Addresses              address_id        INTEGER
# 4             Customer_Addresses               date_from       DATETIME
# 5             Customer_Addresses                 date_to       DATETIME
# 6                Customer_Orders                order_id        INTEGER
# 7                Customer_Orders             customer_id        INTEGER
# 8                Customer_Orders       order_status_code    VARCHAR(10)
# 9                Customer_Orders              order_date       DATETIME
# 10                     Customers             customer_id        INTEGER
# 11                     Customers     payment_method_code    VARCHAR(10)
# ...

# %%
import json
from json import JSONDecodeError
res = "[\"tables\",\"columns\",\"yorks\"]"
res1 = "[tables\",\"columns\",\"yorks\"]"
dict_content = "{\n  \"artwork\": [\"Artwork_ID\", \"Type\"],\n  \"nomination\": [\"Artwork_ID\", \"Festival_ID\", \"Result\"],\n  \"festival_detail\": [\"Festival_ID\", \"Festival_Name\", \"Chair_Name\", \"Year\"]\n}"

tmplist = []
tmplist = json.loads(res)
if tmplist:
    print(tmplist)
else:
    print('empty')
# Out:
# ['tables', 'columns', 'yorks']
